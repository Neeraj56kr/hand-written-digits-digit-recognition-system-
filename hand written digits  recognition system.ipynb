# %% [markdown]
# # import Essential libraries

# %% [raw]
# 		a. Mnist data 60000 sample digit data
# 			--> Tensorflow is used for deep learning.
# 			--> Sequential create neural network layers in Sequence
# 			--> Dense creates fully connected layers
# 			--> Flatten converts 2D IMAGE data into 1D vector
# --> Matplotlib is used for graphs

# %%
import numpy as np 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # load datasets

# %%
(x_train,y_train),(x_test, y_test)=mnist.load_data()

# %% [raw]
# This loads the MNISt DATASET
# 			x_train contains 60,000 traning images
# 			y_train contains lavels for training image
# 			x_test contains 10,000 testing images
# 			y_test contains labels for tesgting image
# Each image size 28 X 28

# %% [markdown]
# # normalize data

# %%
x_train=x_train/255.0
y_test=y_test/255.0

# %% [raw]
# Pixcel values range from 0 to 255 . Dividing by 255 converts values into the range 0 to 1

# %% [markdown]
# # build ANN model

# %%
model=Sequential([
    #convert 28 X 28 image into 1D array
    Flatten(input_shape=(28,28)),
    # hidden layer1
    Dense(128,activation='relu'),
    # hidden layer2
    Dense(64,activation='relu'),
    # output layer
    Dense(10,activation='softmax'),
])

# %% [raw]
# Model Architecture
# 	 Flatten layer :convert 28X28 image into 784 values
# 	 Dense layer (128 nurons): learns important feature using Relue activation.
# 	 Dense layer (64 nurons): learns deeper pattern
# 	 Output layer : 10 neurons represent digits 0-9 .Softmax converts output into probabilities

# %% [markdown]
# # compile model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# # train model

# %%
res=model.fit(
    x_train,
    y_train,
    epochs=200,
    validation_data=(x_test,y_test)
)
# Out:
# Epoch 1/200
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9306 - loss: 0.2360 - val_accuracy: 0.0963 - val_loss: 2757.7065
# Epoch 2/200
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9695 - loss: 0.1010 - val_accuracy: 0.0966 - val_loss: 2829.7925
# Epoch 3/200
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9783 - loss: 0.0703 - val_accuracy: 0.0972 - val_loss: 3310.9275
# Epoch 4/200
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9826 - loss: 0.0548 - val_accuracy: 0.0971 - val_loss: 3642.6265
# Epoch 5/200
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9863 - loss: 0.0417 - val_accuracy: 0.0969 - val_loss: 3919.5903
# Epoch 6/200
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9884 - loss: 0.0354 - val_accuracy: 0.0972 - val_loss: 4150.1963
# Epoch 7/200
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9905 - loss: 0.0279 - val_accuracy: 0.0969 - val_loss: 4726.0381
# Epoch 8/200
# ...

# %% [raw]
# 	The model learns from traning data epochs=10 mean the dataset is trained 10 times.
# 	Validagtion_data check prerformance on unseen test data

# %%
# save the mmodel
model.save("Ann_model.keras")

# %%
# Evaluatione model
loss, accuracy=model.evaluate(x_test,y_test)
print("the accuracy",accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0971 - loss: 42812.2344
# the accuracy 0.09709999710321426

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# Load dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Display first 10 images
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(y_train[i])
    plt.axis('off')

plt.show()
